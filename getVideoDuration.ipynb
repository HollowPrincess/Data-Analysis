# %%
from getVideosDurationInThemeForUser import getDuration
videoDurationDF=getDuration()

# %%
videoDurationDF
# Out:
#                              course_id                          theme_id  \
# 0    course-v1:spbu+SOCLAB+spring_2018  061d8a5b581a45dab40b1ca9405ddf5b
# 1    course-v1:spbu+SOCLAB+spring_2018  061d8a5b581a45dab40b1ca9405ddf5b
# 2    course-v1:spbu+SOCLAB+spring_2018  061d8a5b581a45dab40b1ca9405ddf5b
# 3    course-v1:spbu+SOCLAB+spring_2018  061d8a5b581a45dab40b1ca9405ddf5b
# 4    course-v1:spbu+SOCLAB+spring_2018  061d8a5b581a45dab40b1ca9405ddf5b
# 5    course-v1:spbu+SOCLAB+spring_2018  061d8a5b581a45dab40b1ca9405ddf5b
# 6    course-v1:spbu+SOCLAB+spring_2018  061d8a5b581a45dab40b1ca9405ddf5b
# 7    course-v1:spbu+SOCLAB+spring_2018  061d8a5b581a45dab40b1ca9405ddf5b
# 8    course-v1:spbu+SOCLAB+spring_2018  0edf9012bff546778914358cd1e48f4e
# 9    course-v1:spbu+SOCLAB+spring_2018  0edf9012bff546778914358cd1e48f4e
# 10   course-v1:spbu+SOCLAB+spring_2018  0edf9012bff546778914358cd1e48f4e
# 11   course-v1:spbu+SOCLAB+spring_2018  0edf9012bff546778914358cd1e48f4e
# ...
