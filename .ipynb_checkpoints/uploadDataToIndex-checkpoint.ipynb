# %%
from elasticsearch import Elasticsearch
from elasticsearch.helpers import bulk
import ndjson
import copy 

def gendata():    
    for obj in data:
        if 'event' in obj:
            if 'options' in obj['event']:
                if type(obj['event']['options']) is list:
                    obj['event']['arr_options'] =copy.deepcopy(obj['event']['options'])   
                    del obj['event']['options']
            
            if type(obj['event']) is str:                
                obj['str_event'] = obj.pop('event') 
            elif type(obj['event']) is list:
                obj['list_event'] = obj.pop('event')
                
            
        
        
        yield {
            "_index": "online_courses_full",
            "_type": "doc",
            "_source": obj
        }
        
settings={
    "index.mapping.total_fields.limit": 1000000
}

es = Elasticsearch([{"host": "localhost", "port": 9200}])
"""
if es.indices.exists("online_courses_full"):
    es.indices.delete("online_courses_full")

es.indices.create(index="online_courses_full", body=settings)
"""
with open("data/acadru.json", "r") as read_file:
    data = ndjson.load(read_file)
    bulk(es, gendata())
# Out:
# ---------------------------------------------------------------------------
# BulkIndexError                            Traceback (most recent call last)
# <ipython-input-3-39a193ac3248> in <module>()
#      39 with open("data/acadru.json", "r") as read_file:
#      40     data = ndjson.load(read_file)
# ---> 41     bulk(es, gendata())
#
# ~\Anaconda3\lib\site-packages\elasticsearch\helpers\__init__.py in bulk(client, actions, stats_only, *args, **kwargs)
#     255     # make streaming_bulk yield successful results so we can count them
#     256     kwargs['yield_ok'] = True
# --> 257     for ok, item in streaming_bulk(client, actions, *args, **kwargs):
#     258         # go through request-reponse pairs and detect failures
#     259         if not ok:
#
# ~\Anaconda3\lib\site-packages\elasticsearch\helpers\__init__.py in streaming_bulk(client, actions, chunk_size, max_chunk_bytes, raise_on_error, expand_action_callback, raise_on_exception, max_retries, initial_backoff, max_backoff, yield_ok, *args, **kwargs)
#     190                             _process_bulk_chunk(client, bulk_actions, bulk_data,
#     191                                                 raise_on_exception,
# --> 192                                                 raise_on_error, *args, **kwargs)
#     193                         ):
#     194
#
# ~\Anaconda3\lib\site-packages\elasticsearch\helpers\__init__.py in _process_bulk_chunk(client, bulk_actions, bulk_data, raise_on_exception, raise_on_error, *args, **kwargs)
#     135
#     136     if errors:
# --> 137         raise BulkIndexError('%i document(s) failed to index.' % len(errors), errors)
#     138
#     139 def streaming_bulk(client, actions, chunk_size=500, max_chunk_bytes=100 * 1024 * 1024,
#
# BulkIndexError: ('500 document(s) failed to index.', [{'index': {'_index': 'online_courses_full', '_type': 'doc', '_id': 'GX8q5WoBrzhADuay_eA1', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': "failed to parse field [username] of type [long] in document with id 'GX8q5WoBrzhADuay_eA1'", 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'For input string: "fa832d139bf11518c3ad7fde6335234fa1320a92e0e566d178775a330ac1063e"'}}, 'data': {'username': 'fa832d139bf11518c3ad7fde6335234fa1320a92e0e566d178775a330ac1063e', 'event_type': '/course/course-v1:spbu+ACADRU+spring_2018', 'ip': '7af55f38a2bb349fa231bc0898675630d000a2c73b87fd927e142aff49b85da6', 'agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36', 'host': 'studio.openedu.ru', 'referer': 'https://studio.openedu.ru/home/', 'accept_language': 'ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7', 'event_source': 'server', 'context': {'user_id': 394310, 'org_id': '', 'course_id': '', 'path': '/course/course-v1:spbu+ACADRU+spring_2018'}, 'time': '2018-02-16T23:51:50.693530+00:00', 'page': None, 'str_event': '{"POST": {}, "GET": {}}'}}}, {'index': {'_index': 'online_courses_full', '_type': 'doc', '_id': 'Gn8q5WoBrzhADuay_eA1', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': "failed to parse field [username] of type [long] in document with id 'Gn8q5WoBrzhADuay_eA1'", 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'For input string: "fa832d139bf11518c3ad7fde6335234fa1320a92e0e566d178775a330ac1063e"'}}, 'data': {'username': 'fa832d139bf11518c3ad7fde6335234fa1320a92e0e566d178775a330ac1063e', 'event_type': '/courses/course-v1:spbu+ACADRU+spring_2018/jump_to/block-v1:spbu+ACADRU+spring_2018+type@course+block@course', 'ip': '7af55f38a2bb349fa231bc0898675630d000a2c73b87fd927e142aff49b85da6', 'agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36', 'host': 'courses.openedu.ru', 'referer': 'https://studio.openedu.ru/course/course-v1:spbu+ACADRU+spring_2018', 'accept_language': 'ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7', 'event_source': 'server', 'context': {'course_user_tags': {}, 'user_id': 394310, 'org_id': 'spbu', 'course_id': 'course-v1:spbu+ACADRU+spring_2018', 'path': '/courses/course-v1:spbu+ACADRU+spring_2018/jump_to/block-v1:spbu+ACADRU+spring_2018+type@course+block@course'}, 'time': '2018-02-16T23:51:58.446392+00:00', 'page': None, 'str_event': '{"POST": {}, "GET": {}}'}}}, {'index': {'_index': 'online_courses_full', '_type': 'doc', '_id': 'G38q5WoBrzhADuay_eA1', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': "failed to parse field [username] of type [long] in document with id 'G38q5WoBrzhADuay_eA1'", 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'For input string: "fa832d139bf11518c3ad7fde6335234fa1320a92e0e566d178775a330ac1063e"'}}, 'data': {'username': 'fa832d139bf11518c3ad7fde6335234fa1320a92e0e566d178775a330ac1063e', 'event_type': '/courses/course-v1:spbu+ACADRU+spring_2018/courseware', 'ip': '7af55f38a2bb349fa231bc0898675630d000a2c73b87fd927e142aff49b85da6', 'agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36', 'host': 'courses.openedu.ru', 'referer': 'https://studio.openedu.ru/course/course-v1:spbu+ACADRU+spring_2018', 'accept_language': 'ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7', 'event_source': 'server', 'context': {'course_user_tags': {}, 'user_id': 394310, 'org_id': 'spbu', 'course_id': 'course-v1:spbu+ACADRU+spring_2018', 'path': '/courses/course-v1:spbu+ACADRU+spring_2018/courseware'}, 'time': '2018-02-16T23:51:59.142653+00:00', 'page': None, 'str_event': '{"POST": {}, "GET": {"activate_block_id": ["block-v1:spbu+ACADRU+spring_2018+type@course+block@course"]}}'}}}, {'index': {'_index': 'online_courses_full', '_type': 'doc', '_id': 'HH8q5WoBrzhADuay_eA1', 'status': 400, 'err ...

# %%
#96094
