# %%
import pandas as pd
from getMessagiesAmountInThemeForUser import getMessagiesAmount
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel\parentpoller.py:116: UserWarning: Parent poll failed.  If the frontend dies,
#                 the kernel may be left running.  Please let us know
#                 about your system (bitness, Python, etc.) at
#                 ipython-dev@scipy.org
#   ipython-dev@scipy.org""")

# %%
messagiesNum=getMessagiesAmount()

# %%
messagiesNum.to_csv(path_or_buf='messagies_num.csv',index=False)
messagiesNum = pd.read_csv('messagies_num.csv', sep=',', encoding='utf-8')

# %%
messagiesNum
# Out:
#                                course_id                          theme_id  \
# 0    [course-v1:spbu+SOCLAB+spring_2018]  f04d53579de84074918a985304a22c84
# 1    [course-v1:spbu+SOCLAB+spring_2018]  939b37206e654f35ae914dd632a9223e
# 2    [course-v1:spbu+SOCLAB+spring_2018]  18c7ee896d6a4944a137a99b37fcd249
# 3    [course-v1:spbu+SOCLAB+spring_2018]  061d8a5b581a45dab40b1ca9405ddf5b
# 4    [course-v1:spbu+SOCLAB+spring_2018]  6c085a02b1b34426963b93e63d2d4f98
# 5    [course-v1:spbu+SOCLAB+spring_2018]  e3c0abd8380d446c8e9a5fb6b15aeefc
# 6    [course-v1:spbu+SOCLAB+spring_2018]  0edf9012bff546778914358cd1e48f4e
# 7    [course-v1:spbu+SOCLAB+spring_2018]  f5d3ea1438fc4dc399ef4edc441e892f
# 8    [course-v1:spbu+SOCLAB+spring_2018]  92dc03a5e8f1422c86b7ad2027051370
# 9    [course-v1:spbu+SOCLAB+spring_2018]  1d389a136e47425a8ad238c16cc7b72b
# 10   [course-v1:spbu+SOCLAB+spring_2018]  e69c3d2f9bf24dc38f26d516ff72dafc
# ...
