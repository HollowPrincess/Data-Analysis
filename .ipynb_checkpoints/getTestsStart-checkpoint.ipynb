# %%
from queries.getTestsStarts import ret
import pandas as pd

# %%
df=pd.DataFrame(ret()).sort_values(by=['time'])

# %%
df
# Out:
#                              course_id  position problem_type  \
# 0    course-v1:spbu+SOCLAB+spring_2018         4     ungraded
# 1    course-v1:spbu+SOCLAB+spring_2018         4     ungraded
# 2    course-v1:spbu+SOCLAB+spring_2018         2     ungraded
# 3    course-v1:spbu+SOCLAB+spring_2018         5     ungraded
# 4    course-v1:spbu+SOCLAB+spring_2018         2       graded
# 5    course-v1:spbu+SOCLAB+spring_2018         2       graded
# 6    course-v1:spbu+SOCLAB+spring_2018         1       graded
# 7    course-v1:spbu+SOCLAB+spring_2018         4     ungraded
# 8    course-v1:spbu+SOCLAB+spring_2018         2     ungraded
# 9    course-v1:spbu+SOCLAB+spring_2018         5     ungraded
# 10   course-v1:spbu+SOCLAB+spring_2018         2       graded
# 11   course-v1:spbu+SOCLAB+spring_2018         1       graded
# 12   course-v1:spbu+SOCLAB+spring_2018         2       graded
# 13   course-v1:spbu+SOCLAB+spring_2018         4     ungraded
# ...

# %%
df.to_csv(path_or_buf='problems_starts_time.csv',index=False)

# %%
df = pd.read_csv('problems_starts_time.csv', sep=',', encoding='utf-8')
